# %% [markdown]
# To process the data faster, we found that the best way is to call kaggle API and download directly to google colab and unzipped on colab locally.

# %%
! pip install -q kaggle

# %%
from google.colab import files

files.upload()

# %%
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c 'asl-signs'
# Out:
# Downloading asl-signs.zip to /content
# 100% 37.4G/37.4G [04:49<00:00, 166MB/s]
# 100% 37.4G/37.4G [04:49<00:00, 139MB/s]

# %%
! mkdir asl-signs

# %%
! unzip asl-signs.zip -d asl-signs
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: asl-signs/train_landmark_files/61333/644240510.parquet
#   inflating: asl-signs/train_landmark_files/61333/644760785.parquet
#   inflating: asl-signs/train_landmark_files/61333/64714634.parquet
#   inflating: asl-signs/train_landmark_files/61333/647782358.parquet
#   inflating: asl-signs/train_landmark_files/61333/647894613.parquet
#   inflating: asl-signs/train_landmark_files/61333/648219958.parquet
#   inflating: asl-signs/train_landmark_files/61333/648759798.parquet
#   inflating: asl-signs/train_landmark_files/61333/648810695.parquet
#   inflating: asl-signs/train_landmark_files/61333/649793223.parquet
#   inflating: asl-signs/train_landmark_files/61333/650186126.parquet
#   inflating: asl-signs/train_landmark_files/61333/650848108.parquet
#   inflating: asl-signs/train_landmark_files/61333/653707084.parquet
#   inflating: asl-signs/train_landmark_files/61333/653782862.parquet
#   inflating: asl-signs/train_landmark_files/61333/65568424.parquet
#   inflating: asl-signs/train_landmark_files/61333/657420188.parquet
#   inflating: asl-signs/train_landmark_files/61333/65854902.parquet
#   inflating: asl-signs/train_landmark_files/61333/660385057.parquet
#   inflating: asl-signs/train_landmark_files/61333/660629222.parquet
#   inflating: asl-signs/train_landmark_files/61333/660683321.parquet
#   inflating: asl-signs/train_landmark_files/61333/663014465.parquet
#   inflating: asl-signs/train_landmark_files/61333/664019416.parquet
#   inflating: asl-signs/train_landmark_files/61333/665167954.parquet
#   inflating: asl-signs/train_landmark_files/61333/666432204.parquet
#   inflating: asl-signs/train_landmark_files/61333/66856144.parquet
#   inflating: asl-signs/train_landmark_files/61333/668724453.parquet
#   inflating: asl-signs/train_landmark_files/61333/669193773.parquet
#   inflating: asl-signs/train_landmark_files/61333/669252900.parquet
#   inflating: asl-signs/train_landmark_files/61333/669527924.parquet
#   inflating: asl-signs/train_landmark_files/61333/669683902.parquet
#   inflating: asl-signs/train_landmark_files/61333/670179713.parquet
#   inflating: asl-signs/train_landmark_files/61333/670823058.parquet
#   inflating: asl-signs/train_landmark_files/61333/671451447.parquet
#   inflating: asl-signs/train_landmark_files/61333/671509370.parquet
#   inflating: asl-signs/train_landmark_files/61333/671787092.parquet
#   inflating: asl-signs/train_landmark_files/61333/673310977.parquet
#   inflating: asl-signs/train_landmark_files/61333/673546631.parquet
#   inflating: asl-signs/train_landmark_files/61333/674397783.parquet
#   inflating: asl-signs/train_landmark_files/61333/674628120.parquet
#   inflating: asl-signs/train_landmark_files/61333/675643966.parquet
#   inflating: asl-signs/train_landmark_files/61333/676814140.parquet
#   inflating: asl-signs/train_landmark_files/61333/677632542.parquet
#   inflating: asl-signs/train_landmark_files/61333/678015423.parquet
#   inflating: asl-signs/train_landmark_files/61333/679043787.parquet
#   inflating: asl-signs/train_landmark_files/61333/680747740.parquet
#   inflating: asl-signs/train_landmark_files/61333/680835612.parquet
#   inflating: asl-signs/train_landmark_files/61333/681858927.parquet
#   inflating: asl-signs/train_landmark_files/61333/681934295.parquet
#   inflating: asl-signs/train_landmark_files/61333/682819384.parquet
#   inflating: asl-signs/train_landmark_files/61333/683414601.parquet
#   inflating: asl-signs/train_landmark_files/61333/685942533.parquet
#   inflating: asl-signs/train_landmark_files/61333/687513958.parquet
#   inflating: asl-signs/train_landmark_files/61333/687606903.parquet
#   inflating: asl-signs/train_landmark_files/61333/687777890.parquet
#   inflating: asl-signs/train_landmark_files/61333/688495682.parquet
#   inflating: asl-signs/train_landmark_files/61333/688871047.parquet
#   inflating: asl-signs/train_landmark_files/61333/689331103.parquet
#   inflating: asl-signs/train_landmark_files/61333/690790408.parquet
#   inflating: asl-signs/train_landmark_files/61333/691350055.parquet
#   inflating: asl-signs/train_landmark_files/61333/691464156.parquet
#   inflating: asl-signs/train_landmark_files/61333/692133310.parquet
#   inflating: asl-signs/train_landmark_files/61333/692834432.parquet
#   inflating: asl-signs/train_landmark_files/61333/694080549.parquet
#   inflating: asl-signs/train_landmark_files/61333/694280542.parquet
#   inflating: asl-signs/train_landmark_files/61333/696673812.parquet
#   inflating: asl-signs/train_landmark_files/61333/698484077.parquet
#   inflating: asl-signs/train_landmark_files/61333/699953195.parquet
#   inflating: asl-signs/train_landmark_files/61333/700430523.parquet
#   inflating: asl-signs/train_landmark_files/61333/700786952.parquet
#   inflating: asl-signs/train_landmark_files/61333/701035673.parquet
#   inflating: asl-signs/train_landmark_files/61333/702709354.parquet
#   inflating: asl-signs/train_landmark_files/61333/703631211.parquet
#   inflating: asl-signs/train_landmark_files/61333/704053962.parquet
#   inflating: asl-signs/train_landmark_files/61333/704187953.parquet
#   inflating: asl-signs/train_landmark_files/61333/704262475.parquet
#   inflating: asl-signs/train_landmark_files/61333/704688776.parquet
#   inflating: asl-signs/train_landmark_files/61333/706591664.parquet
#   inflating: asl-signs/train_landmark_files/61333/706963339.parquet
#   inflating: asl-signs/train_landmark_files/61333/707038872.parquet
#   inflating: asl-signs/train_landmark_files/61333/707115797.parquet
#   inflating: asl-signs/train_landmark_files/61333/707178315.parquet
#   inflating: asl-signs/train_landmark_files/61333/707501314.parquet
#   inflating: asl-signs/train_landmark_files/61333/708151514.parquet
#   inflating: asl-signs/train_landmark_files/61333/710020510.parquet
#   inflating: asl-signs/train_landmark_files/61333/710378793.parquet
#   inflating: asl-signs/train_landmark_files/61333/711036009.parquet
#   inflating: asl-signs/train_landmark_files/61333/713559670.parquet
#   inflating: asl-signs/train_landmark_files/61333/713798523.parquet
#   inflating: asl-signs/train_landmark_files/61333/714831568.parquet
#   inflating: asl-signs/train_landmark_files/61333/715246788.parquet
#   inflating: asl-signs/train_landmark_files/61333/715383896.parquet
#   inflating: asl-signs/train_landmark_files/61333/71614080.parquet
#   inflating: asl-signs/train_landmark_files/61333/71701496.parquet
#   inflating: asl-signs/train_landmark_files/61333/71733975.parquet
#   inflating: asl-signs/train_landmark_files/61333/717391955.parquet
#   inflating: asl-signs/train_landmark_files/61333/71778822.parquet
#   inflating: asl-signs/train_landmark_files/61333/71842609.parquet
#   inflating: asl-signs/train_landmark_files/61333/718999699.parquet
#   inflating: asl-signs/train_landmark_files/61333/719042208.parquet
#   inflating: asl-signs/train_landmark_files/61333/719238117.parquet
#   inflating: asl-signs/train_landmark_files/61333/719250462.parquet
#   inflating: asl-signs/train_landmark_files/61333/720214811.parquet
#   inflating: asl-signs/train_landmark_files/61333/720244903.parquet
#   inflating: asl-signs/train_landmark_files/61333/721339003.parquet
#   inflating: asl-signs/train_landmark_files/61333/722259907.parquet
#   inflating: asl-signs/train_landmark_files/61333/722782917.parquet
#   inflating: asl-signs/train_landmark_files/61333/723092071.parquet
#   inflating: asl-signs/train_landmark_files/61333/723153981.parquet
#   inflating: asl-signs/train_landmark_files/61333/723532758.parquet
#   inflating: asl-signs/train_landmark_files/61333/7240627.parquet
#   inflating: asl-signs/train_landmark_files/61333/724072222.parquet
#   inflating: asl-signs/train_landmark_files/61333/725140921.parquet
#   inflating: asl-signs/train_landmark_files/61333/725580968.parquet
#   inflating: asl-signs/train_landmark_files/61333/726791547.parquet
#   inflating: asl-signs/train_landmark_files/61333/728519905.parquet
#   inflating: asl-signs/train_landmark_files/61333/729867886.parquet
#   inflating: asl-signs/train_landmark_files/61333/73011028.parquet
#   inflating: asl-signs/train_landmark_files/61333/730717209.parquet
#   inflating: asl-signs/train_landmark_files/61333/731485643.parquet
#   inflating: asl-signs/train_landmark_files/61333/733624519.parquet
#   inflating: asl-signs/train_landmark_files/61333/735880191.parquet
#   inflating: asl-signs/train_landmark_files/61333/73675895.parquet
#   inflating: asl-signs/train_landmark_files/61333/736942848.parquet
#   inflating: asl-signs/train_landmark_files/61333/737286313.parquet
#   inflating: asl-signs/train_landmark_files/61333/737950067.parquet
#   inflating: asl-signs/train_landmark_files/61333/739821689.parquet
#   inflating: asl-signs/train_landmark_files/61333/74005784.parquet
#   inflating: asl-signs/train_landmark_files/61333/74025492.parquet
#   inflating: asl-signs/train_landmark_files/61333/74116145.parquet
#   inflating: asl-signs/train_landmark_files/61333/743324229.parquet
#   inflating: asl-signs/train_landmark_files/61333/743603833.parquet
#   inflating: asl-signs/train_landmark_files/61333/744296137.parquet
#   inflating: asl-signs/train_landmark_files/61333/744305639.parquet
#   inflating: asl-signs/train_landmark_files/61333/745169282.parquet
#   inflating: asl-signs/train_landmark_files/61333/745339545.parquet
#   inflating: asl-signs/train_landmark_files/61333/747664373.parquet
#   inflating: asl-signs/train_landmark_files/61333/748523928.parquet
#   inflating: asl-signs/train_landmark_files/61333/748633784.parquet
#   inflating: asl-signs/train_landmark_files/61333/749641383.parquet
#   inflating: asl-signs/train_landmark_files/61333/751212363.parquet
#   inflating: asl-signs/train_landmark_files/61333/751411473.parquet
#   inflating: asl-signs/train_landmark_files/61333/751779153.parquet
#   inflating: asl-signs/train_landmark_files/61333/751781114.parquet
#   inflating: asl-signs/train_landmark_files/61333/752000329.parquet
#   inflating: asl-signs/train_landmark_files/61333/752261885.parquet
#   inflating: asl-signs/train_landmark_files/61333/752446068.parquet
#   inflating: asl-signs/train_landmark_files/61333/753253651.parquet
#   inflating: asl-signs/train_landmark_files/61333/753664260.parquet
#   inflating: asl-signs/train_landmark_files/61333/754163674.parquet
#   inflating: asl-signs/train_landmark_files/61333/756888627.parquet
#   inflating: asl-signs/train_landmark_files/61333/757142783.parquet
#   inflating: asl-signs/train_landmark_files/61333/757404034.parquet
#   inflating: asl-signs/train_landmark_files/61333/757657073.parquet
#   inflating: asl-signs/train_landmark_files/61333/758124207.parquet
#   inflating: asl-signs/train_landmark_files/61333/758591428.parquet
#   inflating: asl-signs/train_landmark_files/61333/760373567.parquet
#   inflating: asl-signs/train_landmark_files/61333/761942919.parquet
#   inflating: asl-signs/train_landmark_files/61333/762461867.parquet
#   inflating: asl-signs/train_landmark_files/61333/762480368.parquet
#   inflating: asl-signs/train_landmark_files/61333/763672195.parquet
#   inflating: asl-signs/train_landmark_files/61333/765437750.parquet
#   inflating: asl-signs/train_landmark_files/61333/767218813.parquet
#   inflating: asl-signs/train_landmark_files/61333/767712287.parquet
#   inflating: asl-signs/train_landmark_files/61333/76815729.parquet
#   inflating: asl-signs/train_landmark_files/61333/770358111.parquet
#   inflating: asl-signs/train_landmark_files/61333/77072403.parquet
#   inflating: asl-signs/train_landmark_files/61333/77173065.parquet
#   inflating: asl-signs/train_landmark_files/61333/773414290.parquet
#   inflating: asl-signs/train_landmark_files/61333/775362596.parquet
#   inflating: asl-signs/train_landmark_files/61333/775632947.parquet
#   inflating: asl-signs/train_landmark_files/61333/776690777.parquet
#   inflating: asl-signs/train_landmark_files/61333/77905996.parquet
#   inflating: asl-signs/train_landmark_files/61333/781351346.parquet
#   inflating: asl-signs/train_landmark_files/61333/782131491.parquet
#   inflating: asl-signs/train_landmark_files/61333/782379500.parquet
#   inflating: asl-signs/train_landmark_files/61333/782720175.parquet
#   inflating: asl-signs/train_landmark_files/61333/783712836.parquet
#   inflating: asl-signs/train_landmark_files/61333/785258172.parquet
#   inflating: asl-signs/train_landmark_files/61333/786592893.parquet
#   inflating: asl-signs/train_landmark_files/61333/787760640.parquet
#   inflating: asl-signs/train_landmark_files/61333/792159519.parquet
#   inflating: asl-signs/train_landmark_files/61333/792931535.parquet
#   inflating: asl-signs/train_landmark_files/61333/793121464.parquet
#   inflating: asl-signs/train_landmark_files/61333/793656609.parquet
#   inflating: asl-signs/train_landmark_files/61333/793827308.parquet
#   inflating: asl-signs/train_landmark_files/61333/794306100.parquet
#   inflating: asl-signs/train_landmark_files/61333/794869680.parquet
#   inflating: asl-signs/train_landmark_files/61333/797697472.parquet
#   inflating: asl-signs/train_landmark_files/61333/797850220.parquet
#   inflating: asl-signs/train_landmark_files/61333/798356165.parquet
#   inflating: asl-signs/train_landmark_files/61333/80070647.parquet
#   inflating: asl-signs/train_landmark_files/61333/801863561.parquet
#   inflating: asl-signs/train_landmark_files/61333/802394070.parquet
#   inflating: asl-signs/train_landmark_files/61333/803714392.parquet
#   inflating: asl-signs/train_landmark_files/61333/805065291.parquet
#   inflating: asl-signs/train_landmark_files/61333/805879143.parquet
#   inflating: asl-signs/train_landmark_files/61333/806191150.parquet
#   inflating: asl-signs/train_landmark_files/61333/807349834.parquet
#   inflating: asl-signs/train_landmark_files/61333/807822674.parquet
#   inflating: asl-signs/train_landmark_files/61333/80991154.parquet
#   inflating: asl-signs/train_landmark_files/61333/81190480.parquet
#   inflating: asl-signs/train_landmark_files/61333/812033323.parquet
#   inflating: asl-signs/train_landmark_files/61333/812750579.parquet
#   inflating: asl-signs/train_landmark_files/61333/813180033.parquet
#   inflating: asl-signs/train_landmark_files/61333/816059331.parquet
#   inflating: asl-signs/train_landmark_files/61333/816124900.parquet
#   inflating: asl-signs/train_landmark_files/61333/818028698.parquet
#   inflating: asl-signs/train_landmark_files/61333/81807854.parquet
#   inflating: asl-signs/train_landmark_files/61333/818232200.parquet
#   inflating: asl-signs/train_landmark_files/61333/819299140.parquet
#   inflating: asl-signs/train_landmark_files/61333/820815303.parquet
#   inflating: asl-signs/train_landmark_files/61333/822252961.parquet
#   inflating: asl-signs/train_landmark_files/61333/822807622.parquet
#   inflating: asl-signs/train_landmark_files/61333/826310217.parquet
#   inflating: asl-signs/train_landmark_files/61333/826574622.parquet
#   inflating: asl-signs/train_landmark_files/61333/826638612.parquet
#   inflating: asl-signs/train_landmark_files/61333/82738868.parquet
#   inflating: asl-signs/train_landmark_files/61333/828363771.parquet
#   inflating: asl-signs/train_landmark_files/61333/829548579.parquet
#   inflating: asl-signs/train_landmark_files/61333/83108794.parquet
#   inflating: asl-signs/train_landmark_files/61333/831778453.parquet
#   inflating: asl-signs/train_landmark_files/61333/832741159.parquet
#   inflating: asl-signs/train_landmark_files/61333/833650060.parquet
#   inflating: asl-signs/train_landmark_files/61333/833792112.parquet
#   inflating: asl-signs/train_landmark_files/61333/834613256.parquet
#   inflating: asl-signs/train_landmark_files/61333/835259039.parquet
#   inflating: asl-signs/train_landmark_files/61333/83608846.parquet
#   inflating: asl-signs/train_landmark_files/61333/836412748.parquet
#   inflating: asl-signs/train_landmark_files/61333/836502664.parquet
#   inflating: asl-signs/train_landmark_files/61333/836954816.parquet
#   inflating: asl-signs/train_landmark_files/61333/837472947.parquet
#   inflating: asl-signs/train_landmark_files/61333/838728543.parquet
#   inflating: asl-signs/train_landmark_files/61333/839417835.parquet
#   inflating: asl-signs/train_landmark_files/61333/839718352.parquet
#   inflating: asl-signs/train_landmark_files/61333/84060584.parquet
#   inflating: asl-signs/train_landmark_files/61333/840729390.parquet
#   inflating: asl-signs/train_landmark_files/61333/841444885.parquet
#   inflating: asl-signs/train_landmark_files/61333/842676230.parquet
#   inflating: asl-signs/train_landmark_files/61333/843721214.parquet
#   inflating: asl-signs/train_landmark_files/61333/843927015.parquet
#   inflating: asl-signs/train_landmark_files/61333/844187551.parquet
#   inflating: asl-signs/train_landmark_files/61333/844671736.parquet
#   inflating: asl-signs/train_landmark_files/61333/845397874.parquet
#   inflating: asl-signs/train_landmark_files/61333/84601516.parquet
#   inflating: asl-signs/train_landmark_files/61333/846425086.parquet
#   inflating: asl-signs/train_landmark_files/61333/846592155.parquet
#   inflating: asl-signs/train_landmark_files/61333/846677573.parquet
#   inflating: asl-signs/train_landmark_files/61333/847485367.parquet
#   inflating: asl-signs/train_landmark_files/61333/848602077.parquet
#   inflating: asl-signs/train_landmark_files/61333/848742441.parquet
#   inflating: asl-signs/train_landmark_files/61333/849006440.parquet
#   inflating: asl-signs/train_landmark_files/61333/850214078.parquet
#   inflating: asl-signs/train_landmark_files/61333/850307419.parquet
#   inflating: asl-signs/train_landmark_files/61333/850761185.parquet
#   inflating: asl-signs/train_landmark_files/61333/851263964.parquet
#   inflating: asl-signs/train_landmark_files/61333/851476379.parquet
#   inflating: asl-signs/train_landmark_files/61333/851528622.parquet
#   inflating: asl-signs/train_landmark_files/61333/851691455.parquet
#   inflating: asl-signs/train_landmark_files/61333/852322146.parquet
#   inflating: asl-signs/train_landmark_files/61333/853379289.parquet
#   inflating: asl-signs/train_landmark_files/61333/853844378.parquet
#   inflating: asl-signs/train_landmark_files/61333/854474681.parquet
#   inflating: asl-signs/train_landmark_files/61333/856404560.parquet
#   inflating: asl-signs/train_landmark_files/61333/856859817.parquet
#   inflating: asl-signs/train_landmark_files/61333/857338787.parquet
#   inflating: asl-signs/train_landmark_files/61333/85763204.parquet
#   inflating: asl-signs/train_landmark_files/61333/857965002.parquet
#   inflating: asl-signs/train_landmark_files/61333/858637238.parquet
#   inflating: asl-signs/train_landmark_files/61333/859975032.parquet
#   inflating: asl-signs/train_landmark_files/61333/860128503.parquet
#   inflating: asl-signs/train_landmark_files/61333/860340658.parquet
#   inflating: asl-signs/train_landmark_files/61333/863651668.parquet
#   inflating: asl-signs/train_landmark_files/61333/864625259.parquet
#   inflating: asl-signs/train_landmark_files/61333/865714919.parquet
#   inflating: asl-signs/train_landmark_files/61333/865950408.parquet
#   inflating: asl-signs/train_landmark_files/61333/867372567.parquet
#   inflating: asl-signs/train_landmark_files/61333/867524079.parquet
#   inflating: asl-signs/train_landmark_files/61333/867787474.parquet
#   inflating: asl-signs/train_landmark_files/61333/869225376.parquet
#   inflating: asl-signs/train_landmark_files/61333/869436934.parquet
#   inflating: asl-signs/train_landmark_files/61333/869950232.parquet
#   inflating: asl-signs/train_landmark_files/61333/870319238.parquet
#   inflating: asl-signs/train_landmark_files/61333/870515162.parquet
#   inflating: asl-signs/train_landmark_files/61333/870622816.parquet
#   inflating: asl-signs/train_landmark_files/61333/871058471.parquet
#   inflating: asl-signs/train_landmark_files/61333/871494479.parquet
#   inflating: asl-signs/train_landmark_files/61333/872959605.parquet
#   inflating: asl-signs/train_landmark_files/61333/873019160.parquet
#   inflating: asl-signs/train_landmark_files/61333/873029639.parquet
#   inflating: asl-signs/train_landmark_files/61333/875085242.parquet
#   inflating: asl-signs/train_landmark_files/61333/875778973.parquet
#   inflating: asl-signs/train_landmark_files/61333/87677684.parquet
#   inflating: asl-signs/train_landmark_files/61333/876998139.parquet
#   inflating: asl-signs/train_landmark_files/61333/877138077.parquet
#   inflating: asl-signs/train_landmark_files/61333/87716844.parquet
#   inflating: asl-signs/train_landmark_files/61333/878164567.parquet
#   inflating: asl-signs/train_landmark_files/61333/878898373.parquet
#   inflating: asl-signs/train_landmark_files/61333/880001939.parquet
#   inflating: asl-signs/train_landmark_files/61333/881632642.parquet
#   inflating: asl-signs/train_landmark_files/61333/882521199.parquet
#   inflating: asl-signs/train_landmark_files/61333/882993123.parquet
#   inflating: asl-signs/train_landmark_files/61333/883504807.parquet
#   inflating: asl-signs/train_landmark_files/61333/885944156.parquet
#   inflating: asl-signs/train_landmark_files/61333/886108244.parquet
#   inflating: asl-signs/train_landmark_files/61333/886790641.parquet
#   inflating: asl-signs/train_landmark_files/61333/887140432.parquet
#   inflating: asl-signs/train_landmark_files/61333/887237820.parquet
#   inflating: asl-signs/train_landmark_files/61333/88737369.parquet
#   inflating: asl-signs/train_landmark_files/61333/887599745.parquet
#   inflating: asl-signs/train_landmark_files/61333/887869164.parquet
#   inflating: asl-signs/train_landmark_files/61333/888519388.parquet
#   inflating: asl-signs/train_landmark_files/61333/890668351.parquet
#   inflating: asl-signs/train_landmark_files/61333/891538687.parquet
#   inflating: asl-signs/train_landmark_files/61333/892810372.parquet
#   inflating: asl-signs/train_landmark_files/61333/893491953.parquet
#   inflating: asl-signs/train_landmark_files/61333/894716018.parquet
#   inflating: asl-signs/train_landmark_files/61333/899207732.parquet
#   inflating: asl-signs/train_landmark_files/61333/899417121.parquet
#   inflating: asl-signs/train_landmark_files/61333/899522774.parquet
#   inflating: asl-signs/train_landmark_files/61333/900455160.parquet
#   inflating: asl-signs/train_landmark_files/61333/900853153.parquet
#   inflating: asl-signs/train_landmark_files/61333/900934850.parquet
#   inflating: asl-signs/train_landmark_files/61333/901699500.parquet
#   inflating: asl-signs/train_landmark_files/61333/902023149.parquet
#   inflating: asl-signs/train_landmark_files/61333/902202653.parquet
#   inflating: asl-signs/train_landmark_files/61333/903080874.parquet
#   inflating: asl-signs/train_landmark_files/61333/903846785.parquet
#   inflating: asl-signs/train_landmark_files/61333/903894627.parquet
#   inflating: asl-signs/train_landmark_files/61333/903916969.parquet
#   inflating: asl-signs/train_landmark_files/61333/904846732.parquet
#   inflating: asl-signs/train_landmark_files/61333/9052121.parquet
#   inflating: asl-signs/train_landmark_files/61333/905662511.parquet
#   inflating: asl-signs/train_landmark_files/61333/906863034.parquet
#   inflating: asl-signs/train_landmark_files/61333/907670635.parquet
#   inflating: asl-signs/train_landmark_files/61333/907909102.parquet
#   inflating: asl-signs/train_landmark_files/61333/909078306.parquet
#   inflating: asl-signs/train_landmark_files/61333/909350991.parquet
#   inflating: asl-signs/train_landmark_files/61333/909361459.parquet
#   inflating: asl-signs/train_landmark_files/61333/910760192.parquet
#   inflating: asl-signs/train_landmark_files/61333/912515506.parquet
#   inflating: asl-signs/train_landmark_files/61333/912832800.parquet
#   inflating: asl-signs/train_landmark_files/61333/914203378.parquet
#   inflating: asl-signs/train_landmark_files/61333/915139426.parquet
#   inflating: asl-signs/train_landmark_files/61333/918966386.parquet
#   inflating: asl-signs/train_landmark_files/61333/920497405.parquet
#   inflating: asl-signs/train_landmark_files/61333/923006300.parquet
#   inflating: asl-signs/train_landmark_files/61333/923158358.parquet
#   inflating: asl-signs/train_landmark_files/61333/923195975.parquet
#   inflating: asl-signs/train_landmark_files/61333/924215676.parquet
#   inflating: asl-signs/train_landmark_files/61333/924946141.parquet
#   inflating: asl-signs/train_landmark_files/61333/925115455.parquet
#   inflating: asl-signs/train_landmark_files/61333/928068130.parquet
#   inflating: asl-signs/train_landmark_files/61333/929192516.parquet
#   inflating: asl-signs/train_landmark_files/61333/929891844.parquet
#   inflating: asl-signs/train_landmark_files/61333/930117632.parquet
#   inflating: asl-signs/train_landmark_files/61333/930320377.parquet
#   inflating: asl-signs/train_landmark_files/61333/93063345.parquet
#   inflating: asl-signs/train_landmark_files/61333/9311649.parquet
#   inflating: asl-signs/train_landmark_files/61333/931612987.parquet
#   inflating: asl-signs/train_landmark_files/61333/932638840.parquet
#   inflating: asl-signs/train_landmark_files/61333/933032935.parquet
#   inflating: asl-signs/train_landmark_files/61333/934740748.parquet
#   inflating: asl-signs/train_landmark_files/61333/935453370.parquet
#   inflating: asl-signs/train_landmark_files/61333/936065619.parquet
#   inflating: asl-signs/train_landmark_files/61333/936106432.parquet
#   inflating: asl-signs/train_landmark_files/61333/936917296.parquet
#   inflating: asl-signs/train_landmark_files/61333/937591710.parquet
#   inflating: asl-signs/train_landmark_files/61333/938132393.parquet
#   inflating: asl-signs/train_landmark_files/61333/93814034.parquet
#   inflating: asl-signs/train_landmark_files/61333/939382805.parquet
#   inflating: asl-signs/train_landmark_files/61333/940100783.parquet
#   inflating: asl-signs/train_landmark_files/61333/940108425.parquet
#   inflating: asl-signs/train_landmark_files/61333/940168789.parquet
#   inflating: asl-signs/train_landmark_files/61333/942471036.parquet
#   inflating: asl-signs/train_landmark_files/61333/943318595.parquet
#   inflating: asl-signs/train_landmark_files/61333/944782741.parquet
#   inflating: asl-signs/train_landmark_files/61333/944837812.parquet
#   inflating: asl-signs/train_landmark_files/61333/946418920.parquet
#   inflating: asl-signs/train_landmark_files/61333/947574905.parquet
#   inflating: asl-signs/train_landmark_files/61333/948473053.parquet
#   inflating: asl-signs/train_landmark_files/61333/950246987.parquet
#   inflating: asl-signs/train_landmark_files/61333/951970393.parquet
#   inflating: asl-signs/train_landmark_files/61333/952082155.parquet
#   inflating: asl-signs/train_landmark_files/61333/955134010.parquet
#   inflating: asl-signs/train_landmark_files/61333/955553931.parquet
#   inflating: asl-signs/train_landmark_files/61333/95562818.parquet
#   inflating: asl-signs/train_landmark_files/61333/955912437.parquet
#   inflating: asl-signs/train_landmark_files/61333/956283391.parquet
#   inflating: asl-signs/train_landmark_files/61333/956308964.parquet
#   inflating: asl-signs/train_landmark_files/61333/956493102.parquet
#   inflating: asl-signs/train_landmark_files/61333/957131391.parquet
#   inflating: asl-signs/train_landmark_files/61333/957953885.parquet
#   inflating: asl-signs/train_landmark_files/61333/958602383.parquet
#   inflating: asl-signs/train_landmark_files/61333/959027000.parquet
#   inflating: asl-signs/train_landmark_files/61333/959437686.parquet
#   inflating: asl-signs/train_landmark_files/61333/960063527.parquet
#   inflating: asl-signs/train_landmark_files/61333/96021252.parquet
#   inflating: asl-signs/train_landmark_files/61333/960302297.parquet
#   inflating: asl-signs/train_landmark_files/61333/963466971.parquet
#   inflating: asl-signs/train_landmark_files/61333/964915287.parquet
#   inflating: asl-signs/train_landmark_files/61333/965928018.parquet
#   inflating: asl-signs/train_landmark_files/61333/966619479.parquet
#   inflating: asl-signs/train_landmark_files/61333/967860662.parquet
#   inflating: asl-signs/train_landmark_files/61333/969049401.parquet
#   inflating: asl-signs/train_landmark_files/61333/970120227.parquet
#   inflating: asl-signs/train_landmark_files/61333/97058255.parquet
#   inflating: asl-signs/train_landmark_files/61333/973071252.parquet
#   inflating: asl-signs/train_landmark_files/61333/974000181.parquet
#   inflating: asl-signs/train_landmark_files/61333/974966165.parquet
#   inflating: asl-signs/train_landmark_files/61333/975232910.parquet
#   inflating: asl-signs/train_landmark_files/61333/975629033.parquet
#   inflating: asl-signs/train_landmark_files/61333/976175066.parquet
#   inflating: asl-signs/train_landmark_files/61333/979752327.parquet
#   inflating: asl-signs/train_landmark_files/61333/980111189.parquet
#   inflating: asl-signs/train_landmark_files/61333/981351715.parquet
#   inflating: asl-signs/train_landmark_files/61333/98219612.parquet
#   inflating: asl-signs/train_landmark_files/61333/982638841.parquet
#   inflating: asl-signs/train_landmark_files/61333/984047607.parquet
#   inflating: asl-signs/train_landmark_files/61333/986106911.parquet
#   inflating: asl-signs/train_landmark_files/61333/98771987.parquet
#   inflating: asl-signs/train_landmark_files/61333/987722032.parquet
#   inflating: asl-signs/train_landmark_files/61333/988129612.parquet
#   inflating: asl-signs/train_landmark_files/61333/989570873.parquet
#   inflating: asl-signs/train_landmark_files/61333/990114001.parquet
#   inflating: asl-signs/train_landmark_files/61333/990495423.parquet
#   inflating: asl-signs/train_landmark_files/61333/990733754.parquet
#   inflating: asl-signs/train_landmark_files/61333/990884611.parquet
#   inflating: asl-signs/train_landmark_files/61333/992197855.parquet
#   inflating: asl-signs/train_landmark_files/61333/992550904.parquet
#   inflating: asl-signs/train_landmark_files/61333/993614567.parquet
#   inflating: asl-signs/train_landmark_files/61333/993857868.parquet
#   inflating: asl-signs/train_landmark_files/61333/994191903.parquet
#   inflating: asl-signs/train_landmark_files/61333/99495782.parquet
#   inflating: asl-signs/train_landmark_files/61333/995793615.parquet
#   inflating: asl-signs/train_landmark_files/61333/996662345.parquet
#   inflating: asl-signs/train_landmark_files/61333/998717063.parquet
#   inflating: asl-signs/train_landmark_files/61333/999154577.parquet
#   inflating: asl-signs/train_landmark_files/61333/999641996.parquet
#   inflating: asl-signs/train_landmark_files/62590/1000240708.parquet
#   inflating: asl-signs/train_landmark_files/62590/1002055891.parquet
#   inflating: asl-signs/train_landmark_files/62590/1002160015.parquet
#   inflating: asl-signs/train_landmark_files/62590/1002203166.parquet
#   inflating: asl-signs/train_landmark_files/62590/1002711645.parquet
#   inflating: asl-signs/train_landmark_files/62590/1002825266.parquet
#   inflating: asl-signs/train_landmark_files/62590/1002885072.parquet
#   inflating: asl-signs/train_landmark_files/62590/1003498206.parquet
#   inflating: asl-signs/train_landmark_files/62590/1005973605.parquet
#   inflating: asl-signs/train_landmark_files/62590/1006742163.parquet
#   inflating: asl-signs/train_landmark_files/62590/100728423.parquet
#   inflating: asl-signs/train_landmark_files/62590/1007921043.parquet
#   inflating: asl-signs/train_landmark_files/62590/1010528266.parquet
#   inflating: asl-signs/train_landmark_files/62590/1010691183.parquet
#   inflating: asl-signs/train_landmark_files/62590/1011551679.parquet
#   inflating: asl-signs/train_landmark_files/62590/101254820.parquet
#   inflating: asl-signs/train_landmark_files/62590/1013049724.parquet
#   inflating: asl-signs/train_landmark_files/62590/1013089308.parquet
#   inflating: asl-signs/train_landmark_files/62590/1013176670.parquet
#   inflating: asl-signs/train_landmark_files/62590/1013326498.parquet
#   inflating: asl-signs/train_landmark_files/62590/1014309332.parquet
#   inflating: asl-signs/train_landmark_files/62590/1014384002.parquet
#   inflating: asl-signs/train_landmark_files/62590/101481172.parquet
#   inflating: asl-signs/train_landmark_files/62590/1015438209.parquet
#   inflating: asl-signs/train_landmark_files/62590/101661345.parquet
#   inflating: asl-signs/train_landmark_files/62590/1017601410.parquet
#   inflating: asl-signs/train_landmark_files/62590/101907510.parquet
#   inflating: asl-signs/train_landmark_files/62590/1019811096.parquet
#   inflating: asl-signs/train_landmark_files/62590/1020492846.parquet
#   inflating: asl-signs/train_landmark_files/62590/1020636691.parquet
#   inflating: asl-signs/train_landmark_files/62590/1020690251.parquet
#   inflating: asl-signs/train_landmark_files/62590/1023256181.parquet
#   inflating: asl-signs/train_landmark_files/62590/1025568842.parquet
#   inflating: asl-signs/train_landmark_files/62590/1026529150.parquet
#   inflating: asl-signs/train_landmark_files/62590/1027391960.parquet
#   inflating: asl-signs/train_landmark_files/62590/1027536161.parquet
#   inflating: asl-signs/train_landmark_files/62590/1027923845.parquet
#   inflating: asl-signs/train_landmark_files/62590/102847810.parquet
#   inflating: asl-signs/train_landmark_files/62590/1028680354.parquet
#   inflating: asl-signs/train_landmark_files/62590/1031010390.parquet
#   inflating: asl-signs/train_landmark_files/62590/1031693648.parquet
#   inflating: asl-signs/train_landmark_files/62590/1032052342.parquet
#   inflating: asl-signs/train_landmark_files/62590/1034107946.parquet
#   inflating: asl-signs/train_landmark_files/62590/1034534475.parquet
#   inflating: asl-signs/train_landmark_files/62590/1034885086.parquet
#   inflating: asl-signs/train_landmark_files/62590/1035565428.parquet
#   inflating: asl-signs/train_landmark_files/62590/1036933165.parquet
#   inflating: asl-signs/train_landmark_files/62590/1037505477.parquet
#   inflating: asl-signs/train_landmark_files/62590/1037947715.parquet
#   inflating: asl-signs/train_landmark_files/62590/1038000543.parquet
#   inflating: asl-signs/train_landmark_files/62590/1039263697.parquet
#   inflating: asl-signs/train_landmark_files/62590/1041048209.parquet
#   inflating: asl-signs/train_landmark_files/62590/1041304780.parquet
#   inflating: asl-signs/train_landmark_files/62590/1041859085.parquet
#   inflating: asl-signs/train_landmark_files/62590/1042295381.parquet
#   inflating: asl-signs/train_landmark_files/62590/1044729798.parquet
#   inflating: asl-signs/train_landmark_files/62590/1045787067.parquet
#   inflating: asl-signs/train_landmark_files/62590/104633332.parquet
#   inflating: asl-signs/train_landmark_files/62590/104663714.parquet
#   inflating: asl-signs/train_landmark_files/62590/1046889917.parquet
#   inflating: asl-signs/train_landmark_files/62590/1047094338.parquet
#   inflating: asl-signs/train_landmark_files/62590/1048270730.parquet
#   inflating: asl-signs/train_landmark_files/62590/104949768.parquet
#   inflating: asl-signs/train_landmark_files/62590/1049587865.parquet
#   inflating: asl-signs/train_landmark_files/62590/1050340236.parquet
#   inflating: asl-signs/train_landmark_files/62590/1051197128.parquet
#   inflating: asl-signs/train_landmark_files/62590/1051292249.parquet
#   inflating: asl-signs/train_landmark_files/62590/1051314444.parquet
#   inflating: asl-signs/train_landmark_files/62590/1052027138.parquet
#   inflating: asl-signs/train_landmark_files/62590/1053494625.parquet
#   inflating: asl-signs/train_landmark_files/62590/1057819205.parquet
#   inflating: asl-signs/train_landmark_files/62590/1060007792.parquet
#   inflating: asl-signs/train_landmark_files/62590/1061949915.parquet
#   inflating: asl-signs/train_landmark_files/62590/1061974342.parquet
#   inflating: asl-signs/train_landmark_files/62590/1062602932.parquet
#   inflating: asl-signs/train_landmark_files/62590/106350080.parquet
#   inflating: asl-signs/train_landmark_files/62590/1063757289.parquet
#   inflating: asl-signs/train_landmark_files/62590/1065848323.parquet
#   inflating: asl-signs/train_landmark_files/62590/1066918650.parquet
#   inflating: asl-signs/train_landmark_files/62590/1069580844.parquet
#   inflating: asl-signs/train_landmark_files/62590/1070142106.parquet
#   inflating: asl-signs/train_landmark_files/62590/1070450571.parquet
#   inflating: asl-signs/train_landmark_files/62590/1071644315.parquet
#   inflating: asl-signs/train_landmark_files/62590/107365785.parquet
#   inflating: asl-signs/train_landmark_files/62590/1073774783.parquet
#   inflating: asl-signs/train_landmark_files/62590/1073897367.parquet
#   inflating: asl-signs/train_landmark_files/62590/1074320379.parquet
#   inflating: asl-signs/train_landmark_files/62590/107464090.parquet
#   inflating: asl-signs/train_landmark_files/62590/1074756737.parquet
#   inflating: asl-signs/train_landmark_files/62590/1075507370.parquet
#   inflating: asl-signs/train_landmark_files/62590/1075628786.parquet
#   inflating: asl-signs/train_landmark_files/62590/107658538.parquet
#   inflating: asl-signs/train_landmark_files/62590/1076784034.parquet
#   inflating: asl-signs/train_landmark_files/62590/1077687544.parquet
#   inflating: asl-signs/train_landmark_files/62590/1077751155.parquet
#   inflating: asl-signs/train_landmark_files/62590/1079378813.parquet
#   inflating: asl-signs/train_landmark_files/62590/1079497706.parquet
#   inflating: asl-signs/train_landmark_files/62590/1080233398.parquet
#   inflating: asl-signs/train_landmark_files/62590/1081919158.parquet
#   inflating: asl-signs/train_landmark_files/62590/1082272117.parquet
#   inflating: asl-signs/train_landmark_files/62590/1082351766.parquet
#   inflating: asl-signs/train_landmark_files/62590/1083816707.parquet
#   inflating: asl-signs/train_landmark_files/62590/1084635414.parquet
#   inflating: asl-signs/train_landmark_files/62590/1085188705.parquet
#   inflating: asl-signs/train_landmark_files/62590/1085544042.parquet
#   inflating: asl-signs/train_landmark_files/62590/1086696378.parquet
#   inflating: asl-signs/train_landmark_files/62590/1088562582.parquet
#   inflating: asl-signs/train_landmark_files/62590/1091019114.parquet
#   inflating: asl-signs/train_landmark_files/62590/10938921.parquet
#   inflating: asl-signs/train_landmark_files/62590/1094557535.parquet
#   inflating: asl-signs/train_landmark_files/62590/1094890386.parquet
#   inflating: asl-signs/train_landmark_files/62590/1095286528.parquet
#   inflating: asl-signs/train_landmark_files/62590/109573934.parquet
#   inflating: asl-signs/train_landmark_files/62590/10961564.parquet
#   inflating: asl-signs/train_landmark_files/62590/1097606079.parquet
#   inflating: asl-signs/train_landmark_files/62590/109766449.parquet
#   inflating: asl-signs/train_landmark_files/62590/1097997004.parquet
#   inflating: asl-signs/train_landmark_files/62590/1098379579.parquet
#   inflating: asl-signs/train_landmark_files/62590/1100017326.parquet
#   inflating: asl-signs/train_landmark_files/62590/1101193076.parquet
#   inflating: asl-signs/train_landmark_files/62590/1101574475.parquet
#   inflating: asl-signs/train_landmark_files/62590/1101762513.parquet
#   inflating: asl-signs/train_landmark_files/62590/1102733603.parquet
#   inflating: asl-signs/train_landmark_files/62590/1102883310.parquet
#   inflating: asl-signs/train_landmark_files/62590/110382734.parquet
#   inflating: asl-signs/train_landmark_files/62590/1104093294.parquet
#   inflating: asl-signs/train_landmark_files/62590/110614994.parquet
#   inflating: asl-signs/train_landmark_files/62590/1107044248.parquet
#   inflating: asl-signs/train_landmark_files/62590/1107185813.parquet
#   inflating: asl-signs/train_landmark_files/62590/110726699.parquet
#   inflating: asl-signs/train_landmark_files/62590/1107500088.parquet
#   inflating: asl-signs/train_landmark_files/62590/1108007362.parquet
#   inflating: asl-signs/train_landmark_files/62590/1108072422.parquet
#   inflating: asl-signs/train_landmark_files/62590/110810204.parquet
#   inflating: asl-signs/train_landmark_files/62590/110811729.parquet
#   inflating: asl-signs/train_landmark_files/62590/1108495384.parquet
#   inflating: asl-signs/train_landmark_files/62590/1109409077.parquet
#   inflating: asl-signs/train_landmark_files/62590/1109431495.parquet
#   inflating: asl-signs/train_landmark_files/62590/1111099773.parquet
#   inflating: asl-signs/train_landmark_files/62590/1112119985.parquet
#   inflating: asl-signs/train_landmark_files/62590/1113479383.parquet
#   inflating: asl-signs/train_landmark_files/62590/1114694167.parquet
#   inflating: asl-signs/train_landmark_files/62590/1114832055.parquet
#   inflating: asl-signs/train_landmark_files/62590/1116666857.parquet
#   inflating: asl-signs/train_landmark_files/62590/1118807928.parquet
#   inflating: asl-signs/train_landmark_files/62590/1119762799.parquet
#   inflating: asl-signs/train_landmark_files/62590/1120329389.parquet
#   inflating: asl-signs/train_landmark_files/62590/112075270.parquet
#   inflating: asl-signs/train_landmark_files/62590/1123168001.parquet
#   inflating: asl-signs/train_landmark_files/62590/1123610803.parquet
#   inflating: asl-signs/train_landmark_files/62590/1124849034.parquet
#   inflating: asl-signs/train_landmark_files/62590/1125484288.parquet
#   inflating: asl-signs/train_landmark_files/62590/1125748653.parquet
#   inflating: asl-signs/train_landmark_files/62590/1126447007.parquet
#   inflating: asl-signs/train_landmark_files/62590/1127721990.parquet
#   inflating: asl-signs/train_landmark_files/62590/1129205911.parquet
#   inflating: asl-signs/train_landmark_files/62590/1130795908.parquet
#   inflating: asl-signs/train_landmark_files/62590/1131257263.parquet
#   inflating: asl-signs/train_landmark_files/62590/1131459488.parquet
#   inflating: asl-signs/train_landmark_files/62590/1131783740.parquet
#   inflating: asl-signs/train_landmark_files/62590/1131988238.parquet
#   inflating: asl-signs/train_landmark_files/62590/1132264566.parquet
#   inflating: asl-signs/train_landmark_files/62590/1133223759.parquet
#   inflating: asl-signs/train_landmark_files/62590/113435882.parquet
#   inflating: asl-signs/train_landmark_files/62590/1134725669.parquet
#   inflating: asl-signs/train_landmark_files/62590/1137186202.parquet
#   inflating: asl-signs/train_landmark_files/62590/1137383760.parquet
#   inflating: asl-signs/train_landmark_files/62590/1138124437.parquet
#   inflating: asl-signs/train_landmark_files/62590/1138922154.parquet
#   inflating: asl-signs/train_landmark_files/62590/1139064509.parquet
#   inflating: asl-signs/train_landmark_files/62590/1140340833.parquet
#   inflating: asl-signs/train_landmark_files/62590/1140751816.parquet
#   inflating: asl-signs/train_landmark_files/62590/1141206992.parquet
#   inflating: asl-signs/train_landmark_files/62590/1141285935.parquet
#   inflating: asl-signs/train_landmark_files/62590/1142889577.parquet
#   inflating: asl-signs/train_landmark_files/62590/1142910972.parquet
#   inflating: asl-signs/train_landmark_files/62590/1143048290.parquet
#   inflating: asl-signs/train_landmark_files/62590/1143824599.parquet
#   inflating: asl-signs/train_landmark_files/62590/1145614880.parquet
#   inflating: asl-signs/train_landmark_files/62590/1147317699.parquet
#   inflating: asl-signs/train_landmark_files/62590/1147554270.parquet
#   inflating: asl-signs/train_landmark_files/62590/1148636201.parquet
#   inflating: asl-signs/train_landmark_files/62590/1149196775.parquet
#   inflating: asl-signs/train_landmark_files/62590/1150109087.parquet
#   inflating: asl-signs/train_landmark_files/62590/1150146694.parquet
#   inflating: asl-signs/train_landmark_files/62590/115150751.parquet
#   inflating: asl-signs/train_landmark_files/62590/1151875023.parquet
#   inflating: asl-signs/train_landmark_files/62590/1152133611.parquet
#   inflating: asl-signs/train_landmark_files/62590/115554110.parquet
#   inflating: asl-signs/train_landmark_files/62590/1157491145.parquet
#   inflating: asl-signs/train_landmark_files/62590/1157575215.parquet
#   inflating: asl-signs/train_landmark_files/62590/1157645572.parquet
#   inflating: asl-signs/train_landmark_files/62590/1159530638.parquet
#   inflating: asl-signs/train_landmark_files/62590/1159585648.parquet
#   inflating: asl-signs/train_landmark_files/62590/1160070256.parquet
#   inflating: asl-signs/train_landmark_files/62590/1160188955.parquet
#   inflating: asl-signs/train_landmark_files/62590/1160368452.parquet
#   inflating: asl-signs/train_landmark_files/62590/1161821560.parquet
#   inflating: asl-signs/train_landmark_files/62590/1162427516.parquet
#   inflating: asl-signs/train_landmark_files/62590/1162748514.parquet
#   inflating: asl-signs/train_landmark_files/62590/1163094070.parquet
#   inflating: asl-signs/train_landmark_files/62590/1163337257.parquet
#   inflating: asl-signs/train_landmark_files/62590/1163600312.parquet
#   inflating: asl-signs/train_landmark_files/62590/1164098099.parquet
#   inflating: asl-signs/train_landmark_files/62590/1164797483.parquet
#   inflating: asl-signs/train_landmark_files/62590/1164931174.parquet
#   inflating: asl-signs/train_landmark_files/62590/1165617815.parquet
#   inflating: asl-signs/train_landmark_files/62590/1165657255.parquet
#   inflating: asl-signs/train_landmark_files/62590/1166013737.parquet
#   inflating: asl-signs/train_landmark_files/62590/1166889834.parquet
#   inflating: asl-signs/train_landmark_files/62590/1168002814.parquet
#   inflating: asl-signs/train_landmark_files/62590/1170065489.parquet
#   inflating: asl-signs/train_landmark_files/62590/1170476852.parquet
#   inflating: asl-signs/train_landmark_files/62590/1170937923.parquet
#   inflating: asl-signs/train_landmark_files/62590/1171424376.parquet
#   inflating: asl-signs/train_landmark_files/62590/117273938.parquet
#   inflating: asl-signs/train_landmark_files/62590/1172777168.parquet
#   inflating: asl-signs/train_landmark_files/62590/1173397373.parquet
#   inflating: asl-signs/train_landmark_files/62590/1174132205.parquet
#   inflating: asl-signs/train_landmark_files/62590/1174346662.parquet
#   inflating: asl-signs/train_landmark_files/62590/1174858293.parquet
#   inflating: asl-signs/train_landmark_files/62590/117515132.parquet
#   inflating: asl-signs/train_landmark_files/62590/117579003.parquet
#   inflating: asl-signs/train_landmark_files/62590/1180676712.parquet
#   inflating: asl-signs/train_landmark_files/62590/1181642476.parquet
#   inflating: asl-signs/train_landmark_files/62590/1182128779.parquet
#   inflating: asl-signs/train_landmark_files/62590/1183948822.parquet
#   inflating: asl-signs/train_landmark_files/62590/1183970242.parquet
#   inflating: asl-signs/train_landmark_files/62590/1184227200.parquet
#   inflating: asl-signs/train_landmark_files/62590/1184969258.parquet
#   inflating: asl-signs/train_landmark_files/62590/118571783.parquet
#   inflating: asl-signs/train_landmark_files/62590/1186504018.parquet
#   inflating: asl-signs/train_landmark_files/62590/1188288174.parquet
#   inflating: asl-signs/train_landmark_files/62590/1192237614.parquet
#   inflating: asl-signs/train_landmark_files/62590/11931083.parquet
#   inflating: asl-signs/train_landmark_files/62590/1193369020.parquet
#   inflating: asl-signs/train_landmark_files/62590/1195465999.parquet
#   inflating: asl-signs/train_landmark_files/62590/1195997798.parquet
#   inflating: asl-signs/train_landmark_files/62590/1196518891.parquet
#   inflating: asl-signs/train_landmark_files/62590/1196980728.parquet
#   inflating: asl-signs/train_landmark_files/62590/1197032149.parquet
#   inflating: asl-signs/train_landmark_files/62590/119735519.parquet
#   inflating: asl-signs/train_landmark_files/62590/1198059617.parquet
#   inflating: asl-signs/train_landmark_files/62590/1199866281.parquet
#   inflating: asl-signs/train_landmark_files/62590/1202277755.parquet
# ...
#   inflating: asl-signs/train_landmark_files/62590/801047500.parquet
#   inflating: asl-signs/train_landmark_files/62590/801704205.parquet
#   inflating: asl-signs/train_landmark_files/62590/803802860.parquet
#   inflating: asl-signs/train_landmark_files/62590/804529347.parquet
#   inflating: asl-signs/train_landmark_files/62590/806242322.parquet
#   inflating: asl-signs/train_landmark_files/62590/807211844.parquet
#   inflating: asl-signs/train_landmark_files/62590/80730236.parquet
#   inflating: asl-signs/train_landmark_files/62590/808547061.parquet
#   inflating: asl-signs/train_landmark_files/62590/80901733.parquet
#   inflating: asl-signs/train_landmark_files/62590/809855711.parquet
#   inflating: asl-signs/train_landmark_files/62590/810376056.parquet
#   inflating: asl-signs/train_landmark_files/62590/811001529.parquet
#   inflating: asl-signs/train_landmark_files/62590/811186756.parquet
#   inflating: asl-signs/train_landmark_files/62590/812592580.parquet
#   inflating: asl-signs/train_landmark_files/62590/812940898.parquet
#   inflating: asl-signs/train_landmark_files/62590/815749333.parquet
#   inflating: asl-signs/train_landmark_files/62590/817139186.parquet
#   inflating: asl-signs/train_landmark_files/62590/817234649.parquet
#   inflating: asl-signs/train_landmark_files/62590/817499912.parquet
#   inflating: asl-signs/train_landmark_files/62590/817729964.parquet
#   inflating: asl-signs/train_landmark_files/62590/818435610.parquet
#   inflating: asl-signs/train_landmark_files/62590/818603370.parquet
#   inflating: asl-signs/train_landmark_files/62590/820026810.parquet
#   inflating: asl-signs/train_landmark_files/62590/820665960.parquet
#   inflating: asl-signs/train_landmark_files/62590/820757500.parquet
#   inflating: asl-signs/train_landmark_files/62590/82288159.parquet
#   inflating: asl-signs/train_landmark_files/62590/822995642.parquet
#   inflating: asl-signs/train_landmark_files/62590/82448840.parquet
#   inflating: asl-signs/train_landmark_files/62590/825073402.parquet
#   inflating: asl-signs/train_landmark_files/62590/825398401.parquet
#   inflating: asl-signs/train_landmark_files/62590/825881363.parquet
#   inflating: asl-signs/train_landmark_files/62590/825899666.parquet
#   inflating: asl-signs/train_landmark_files/62590/825955947.parquet
#   inflating: asl-signs/train_landmark_files/62590/826286690.parquet
#   inflating: asl-signs/train_landmark_files/62590/828048506.parquet
#   inflating: asl-signs/train_landmark_files/62590/83023137.parquet
#   inflating: asl-signs/train_landmark_files/62590/83097081.parquet
#   inflating: asl-signs/train_landmark_files/62590/83199551.parquet
#   inflating: asl-signs/train_landmark_files/62590/831997949.parquet
#   inflating: asl-signs/train_landmark_files/62590/832873580.parquet
#   inflating: asl-signs/train_landmark_files/62590/833369393.parquet
#   inflating: asl-signs/train_landmark_files/62590/834679805.parquet
#   inflating: asl-signs/train_landmark_files/62590/835891300.parquet
#   inflating: asl-signs/train_landmark_files/62590/83642124.parquet
#   inflating: asl-signs/train_landmark_files/62590/838814746.parquet
#   inflating: asl-signs/train_landmark_files/62590/840621739.parquet
#   inflating: asl-signs/train_landmark_files/62590/841435944.parquet
#   inflating: asl-signs/train_landmark_files/62590/842498400.parquet
#   inflating: asl-signs/train_landmark_files/62590/842512216.parquet
#   inflating: asl-signs/train_landmark_files/62590/843010503.parquet
#   inflating: asl-signs/train_landmark_files/62590/843956945.parquet
#   inflating: asl-signs/train_landmark_files/62590/844689842.parquet
#   inflating: asl-signs/train_landmark_files/62590/844732425.parquet
#   inflating: asl-signs/train_landmark_files/62590/845151784.parquet
#   inflating: asl-signs/train_landmark_files/62590/845626703.parquet
#   inflating: asl-signs/train_landmark_files/62590/847349469.parquet
#   inflating: asl-signs/train_landmark_files/62590/847478343.parquet
#   inflating: asl-signs/train_landmark_files/62590/848301916.parquet
#   inflating: asl-signs/train_landmark_files/62590/849820287.parquet
#   inflating: asl-signs/train_landmark_files/62590/852357018.parquet
#   inflating: asl-signs/train_landmark_files/62590/853308943.parquet
#   inflating: asl-signs/train_landmark_files/62590/854715595.parquet
#   inflating: asl-signs/train_landmark_files/62590/855008192.parquet
#   inflating: asl-signs/train_landmark_files/62590/856658241.parquet
#   inflating: asl-signs/train_landmark_files/62590/856658758.parquet
#   inflating: asl-signs/train_landmark_files/62590/857330449.parquet
#   inflating: asl-signs/train_landmark_files/62590/857897555.parquet
#   inflating: asl-signs/train_landmark_files/62590/858916415.parquet
#   inflating: asl-signs/train_landmark_files/62590/859360609.parquet
#   inflating: asl-signs/train_landmark_files/62590/860574748.parquet
#   inflating: asl-signs/train_landmark_files/62590/860980211.parquet
#   inflating: asl-signs/train_landmark_files/62590/861194469.parquet
#   inflating: asl-signs/train_landmark_files/62590/861703154.parquet
#   inflating: asl-signs/train_landmark_files/62590/863070030.parquet
#   inflating: asl-signs/train_landmark_files/62590/864890921.parquet
#   inflating: asl-signs/train_landmark_files/62590/864960653.parquet
#   inflating: asl-signs/train_landmark_files/62590/865281099.parquet
#   inflating: asl-signs/train_landmark_files/62590/86577496.parquet
#   inflating: asl-signs/train_landmark_files/62590/865854387.parquet
#   inflating: asl-signs/train_landmark_files/62590/866461102.parquet
#   inflating: asl-signs/train_landmark_files/62590/868017161.parquet
#   inflating: asl-signs/train_landmark_files/62590/869253216.parquet
#   inflating: asl-signs/train_landmark_files/62590/869383735.parquet
#   inflating: asl-signs/train_landmark_files/62590/870050756.parquet
#   inflating: asl-signs/train_landmark_files/62590/873196414.parquet
#   inflating: asl-signs/train_landmark_files/62590/873827929.parquet
#   inflating: asl-signs/train_landmark_files/62590/874438787.parquet
#   inflating: asl-signs/train_landmark_files/62590/874679587.parquet
#   inflating: asl-signs/train_landmark_files/62590/875493877.parquet
#   inflating: asl-signs/train_landmark_files/62590/875586731.parquet
#   inflating: asl-signs/train_landmark_files/62590/876326888.parquet
#   inflating: asl-signs/train_landmark_files/62590/876703972.parquet
#   inflating: asl-signs/train_landmark_files/62590/878427337.parquet
#   inflating: asl-signs/train_landmark_files/62590/879486506.parquet
#   inflating: asl-signs/train_landmark_files/62590/879531007.parquet
#   inflating: asl-signs/train_landmark_files/62590/879744550.parquet
#   inflating: asl-signs/train_landmark_files/62590/880282270.parquet
#   inflating: asl-signs/train_landmark_files/62590/882040589.parquet
#   inflating: asl-signs/train_landmark_files/62590/883189201.parquet
#   inflating: asl-signs/train_landmark_files/62590/883488730.parquet
#   inflating: asl-signs/train_landmark_files/62590/884397854.parquet
#   inflating: asl-signs/train_landmark_files/62590/884900213.parquet
#   inflating: asl-signs/train_landmark_files/62590/885349988.parquet
#   inflating: asl-signs/train_landmark_files/62590/886881775.parquet
#   inflating: asl-signs/train_landmark_files/62590/887758782.parquet
#   inflating: asl-signs/train_landmark_files/62590/889686933.parquet
#   inflating: asl-signs/train_landmark_files/62590/890307156.parquet
#   inflating: asl-signs/train_landmark_files/62590/890379279.parquet
#   inflating: asl-signs/train_landmark_files/62590/890792124.parquet
#   inflating: asl-signs/train_landmark_files/62590/891437590.parquet
#   inflating: asl-signs/train_landmark_files/62590/891562299.parquet
#   inflating: asl-signs/train_landmark_files/62590/893134347.parquet
#   inflating: asl-signs/train_landmark_files/62590/8931750.parquet
#   inflating: asl-signs/train_landmark_files/62590/894502761.parquet
#   inflating: asl-signs/train_landmark_files/62590/895622951.parquet
#   inflating: asl-signs/train_landmark_files/62590/895769740.parquet
#   inflating: asl-signs/train_landmark_files/62590/897491062.parquet
#   inflating: asl-signs/train_landmark_files/62590/899512165.parquet
#   inflating: asl-signs/train_landmark_files/62590/899752077.parquet
#   inflating: asl-signs/train_landmark_files/62590/89986525.parquet
#   inflating: asl-signs/train_landmark_files/62590/900310524.parquet
#   inflating: asl-signs/train_landmark_files/62590/9004697.parquet
#   inflating: asl-signs/train_landmark_files/62590/903483178.parquet
#   inflating: asl-signs/train_landmark_files/62590/909396563.parquet
#   inflating: asl-signs/train_landmark_files/62590/910010424.parquet
#   inflating: asl-signs/train_landmark_files/62590/91067158.parquet
#   inflating: asl-signs/train_landmark_files/62590/911008928.parquet
#   inflating: asl-signs/train_landmark_files/62590/911949162.parquet
#   inflating: asl-signs/train_landmark_files/62590/91257929.parquet
#   inflating: asl-signs/train_landmark_files/62590/913058157.parquet
#   inflating: asl-signs/train_landmark_files/62590/914006603.parquet
#   inflating: asl-signs/train_landmark_files/62590/914077139.parquet
#   inflating: asl-signs/train_landmark_files/62590/914747832.parquet
#   inflating: asl-signs/train_landmark_files/62590/915135124.parquet
#   inflating: asl-signs/train_landmark_files/62590/917208316.parquet
#   inflating: asl-signs/train_landmark_files/62590/919061942.parquet
#   inflating: asl-signs/train_landmark_files/62590/920324644.parquet
#   inflating: asl-signs/train_landmark_files/62590/922150309.parquet
#   inflating: asl-signs/train_landmark_files/62590/922643537.parquet
#   inflating: asl-signs/train_landmark_files/62590/923211026.parquet
#   inflating: asl-signs/train_landmark_files/62590/924236464.parquet
#   inflating: asl-signs/train_landmark_files/62590/92463334.parquet
#   inflating: asl-signs/train_landmark_files/62590/925153277.parquet
#   inflating: asl-signs/train_landmark_files/62590/925180380.parquet
#   inflating: asl-signs/train_landmark_files/62590/925227701.parquet
#   inflating: asl-signs/train_landmark_files/62590/9253753.parquet
#   inflating: asl-signs/train_landmark_files/62590/925442418.parquet
#   inflating: asl-signs/train_landmark_files/62590/925489247.parquet
#   inflating: asl-signs/train_landmark_files/62590/925616803.parquet
#   inflating: asl-signs/train_landmark_files/62590/927021802.parquet
#   inflating: asl-signs/train_landmark_files/62590/928861453.parquet
#   inflating: asl-signs/train_landmark_files/62590/930166446.parquet
#   inflating: asl-signs/train_landmark_files/62590/930399699.parquet
#   inflating: asl-signs/train_landmark_files/62590/931010889.parquet
#   inflating: asl-signs/train_landmark_files/62590/931873038.parquet
#   inflating: asl-signs/train_landmark_files/62590/932086438.parquet
#   inflating: asl-signs/train_landmark_files/62590/932300126.parquet
#   inflating: asl-signs/train_landmark_files/62590/932770641.parquet
#   inflating: asl-signs/train_landmark_files/62590/93338213.parquet
#   inflating: asl-signs/train_landmark_files/62590/933785603.parquet
#   inflating: asl-signs/train_landmark_files/62590/936790414.parquet
#   inflating: asl-signs/train_landmark_files/62590/936792513.parquet
#   inflating: asl-signs/train_landmark_files/62590/937741696.parquet
#   inflating: asl-signs/train_landmark_files/62590/938349687.parquet
#   inflating: asl-signs/train_landmark_files/62590/938564099.parquet
#   inflating: asl-signs/train_landmark_files/62590/939121058.parquet
#   inflating: asl-signs/train_landmark_files/62590/940865832.parquet
#   inflating: asl-signs/train_landmark_files/62590/943565854.parquet
#   inflating: asl-signs/train_landmark_files/62590/944434237.parquet
#   inflating: asl-signs/train_landmark_files/62590/944623386.parquet
#   inflating: asl-signs/train_landmark_files/62590/946402503.parquet
#   inflating: asl-signs/train_landmark_files/62590/946522250.parquet
#   inflating: asl-signs/train_landmark_files/62590/946588681.parquet
#   inflating: asl-signs/train_landmark_files/62590/948648351.parquet
#   inflating: asl-signs/train_landmark_files/62590/948989059.parquet
#   inflating: asl-signs/train_landmark_files/62590/950017446.parquet
#   inflating: asl-signs/train_landmark_files/62590/950302051.parquet
#   inflating: asl-signs/train_landmark_files/62590/950650860.parquet
#   inflating: asl-signs/train_landmark_files/62590/95220205.parquet
#   inflating: asl-signs/train_landmark_files/62590/952524976.parquet
#   inflating: asl-signs/train_landmark_files/62590/955271072.parquet
#   inflating: asl-signs/train_landmark_files/62590/956128313.parquet
#   inflating: asl-signs/train_landmark_files/62590/956335531.parquet
#   inflating: asl-signs/train_landmark_files/62590/957026460.parquet
#   inflating: asl-signs/train_landmark_files/62590/957054627.parquet
#   inflating: asl-signs/train_landmark_files/62590/957147795.parquet
#   inflating: asl-signs/train_landmark_files/62590/957809063.parquet
#   inflating: asl-signs/train_landmark_files/62590/958698240.parquet
#   inflating: asl-signs/train_landmark_files/62590/960158265.parquet
#   inflating: asl-signs/train_landmark_files/62590/960583745.parquet
#   inflating: asl-signs/train_landmark_files/62590/963119053.parquet
#   inflating: asl-signs/train_landmark_files/62590/966263171.parquet
#   inflating: asl-signs/train_landmark_files/62590/968270449.parquet
#   inflating: asl-signs/train_landmark_files/62590/968849240.parquet
#   inflating: asl-signs/train_landmark_files/62590/972349318.parquet
#   inflating: asl-signs/train_landmark_files/62590/972666882.parquet
#   inflating: asl-signs/train_landmark_files/62590/973027570.parquet
#   inflating: asl-signs/train_landmark_files/62590/97308843.parquet
#   inflating: asl-signs/train_landmark_files/62590/973284327.parquet
#   inflating: asl-signs/train_landmark_files/62590/973569124.parquet
#   inflating: asl-signs/train_landmark_files/62590/973901668.parquet
#   inflating: asl-signs/train_landmark_files/62590/974627058.parquet
#   inflating: asl-signs/train_landmark_files/62590/975594861.parquet
#   inflating: asl-signs/train_landmark_files/62590/976522512.parquet
#   inflating: asl-signs/train_landmark_files/62590/976975802.parquet
#   inflating: asl-signs/train_landmark_files/62590/97719604.parquet
#   inflating: asl-signs/train_landmark_files/62590/97803639.parquet
#   inflating: asl-signs/train_landmark_files/62590/978096391.parquet
#   inflating: asl-signs/train_landmark_files/62590/979401943.parquet
#   inflating: asl-signs/train_landmark_files/62590/981079958.parquet
#   inflating: asl-signs/train_landmark_files/62590/981313843.parquet
#   inflating: asl-signs/train_landmark_files/62590/983579416.parquet
#   inflating: asl-signs/train_landmark_files/62590/984270123.parquet
#   inflating: asl-signs/train_landmark_files/62590/98491388.parquet
#   inflating: asl-signs/train_landmark_files/62590/989089039.parquet
#   inflating: asl-signs/train_landmark_files/62590/990459898.parquet
#   inflating: asl-signs/train_landmark_files/62590/990866770.parquet
#   inflating: asl-signs/train_landmark_files/62590/992055318.parquet
#   inflating: asl-signs/train_landmark_files/62590/99217612.parquet
#   inflating: asl-signs/train_landmark_files/62590/993031543.parquet
#   inflating: asl-signs/train_landmark_files/62590/993466760.parquet
#   inflating: asl-signs/train_landmark_files/62590/993904514.parquet
#   inflating: asl-signs/train_landmark_files/62590/99490521.parquet
#   inflating: asl-signs/train_landmark_files/62590/9950818.parquet
#   inflating: asl-signs/train_landmark_files/62590/995270127.parquet
#   inflating: asl-signs/train_landmark_files/62590/998698928.parquet
#   inflating: asl-signs/train_landmark_files/62590/999004932.parquet
#   inflating: asl-signs/train_landmark_files/62590/999231022.parquet
#   inflating: asl-signs/train_landmark_files/62590/999317239.parquet

# %%
# !pip install -q pandas pyarrow
# !pip install -q mediapipe
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 46.8 MB/s eta 0:00:00

# %%
# !ls
# Out:
# asl-signs  asl-signs.zip  kaggle.json  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data Folder Directry
main_dir = '/content/asl-signs/'
googledrive_dir = '/content/drive/MyDrive/Colab Notebooks/Data/asl-signs/'

# %% [markdown]
# During our study of the data and research on the possible model solutions, there is one transformer model approach caught our eye. This transformer model approach was designed by Wijkhuizen, M., in the Kaggle competition (2023). Our project team decided to follow Wijkhuizen, M.’s approach to create a transformer model as one of the models to test for this project. Our goal with this approach is to get a better understanding of the transformer model since Wijkhuizen, M.’s approach is to build a transformer model from scratch and not fine-turn a base model.
#
# Following code are from https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tqdm import tqdm
from sklearn.model_selection import GroupShuffleSplit
import json
# Constants (adjust these according to your data)
INPUT_SIZE = 64
N_COLS = 100  # Adjust based on your landmark indices
N_DIMS = 3    # Typically x, y, z coordinates
N_ROWS = 543

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
# Load metadata
metadata_sub_dir = 'train.csv'
metadata_full_file_path = os.path.join(main_dir, metadata_sub_dir)
df_metadata = pd.read_csv(metadata_full_file_path)

# Load sign to index mapping
signmap_sub_dir = 'sign_to_prediction_index_map.json'
signmap_full_file_path = os.path.join(main_dir, signmap_sub_dir)
with open(signmap_full_file_path, 'r') as file:
    sign_to_index = json.load(file)
df_metadata['sign_index'] = df_metadata['sign'].map(sign_to_index)

# %% [markdown]
# In Wijkhuizen, M.’s transformer approach, all the data has been reformatted to 4D tensor (Number, Frame, KeyPoint, LandMark), where “Number” is the number of data file which also link to a label y for the meaning of signs. “Frame” is the frame of the video recording; if the frame is larger than 64, it will be downsampled, and if the frame is shorter than 64 frames, then it will be padded (2023). “KeyPoint” is the LandMark keypoint from the Mediapipe tracking result; this approach has limited only 66 key points: Lips has 40 key points, the dominant hand has 21 key points, and the dominant side pose has 5 key points, a total of 66 key points. The “LandMark” is 3 LandMark values of [x, y, z] from MediaPipe tracking. This has significantly reduced the size of data that need to be processed by the model and kept the most possible features that are important to ASL recognition.

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
USE_TYPES = ['left_hand', 'pose', 'right_hand']
START_IDX = 468
LIPS_IDXS0 = np.array([
        61, 185, 40, 39, 37, 0, 267, 269, 270, 409,
        291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
        78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
        95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
    ])
# Landmark indices in original data
LEFT_HAND_IDXS0 = np.arange(468,489)
RIGHT_HAND_IDXS0 = np.arange(522,543)
LEFT_POSE_IDXS0 = np.array([502, 504, 506, 508, 510])
RIGHT_POSE_IDXS0 = np.array([503, 505, 507, 509, 511])
LANDMARK_IDXS_LEFT_DOMINANT0 = np.concatenate((LIPS_IDXS0, LEFT_HAND_IDXS0, LEFT_POSE_IDXS0))
LANDMARK_IDXS_RIGHT_DOMINANT0 = np.concatenate((LIPS_IDXS0, RIGHT_HAND_IDXS0, RIGHT_POSE_IDXS0))
HAND_IDXS0 = np.concatenate((LEFT_HAND_IDXS0, RIGHT_HAND_IDXS0), axis=0)
N_COLS = LANDMARK_IDXS_LEFT_DOMINANT0.size
# Landmark indices in processed data
LIPS_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, LIPS_IDXS0)).squeeze()
LEFT_HAND_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, LEFT_HAND_IDXS0)).squeeze()
RIGHT_HAND_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, RIGHT_HAND_IDXS0)).squeeze()
HAND_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, HAND_IDXS0)).squeeze()
POSE_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, LEFT_POSE_IDXS0)).squeeze()

print(f'# HAND_IDXS: {len(HAND_IDXS)}, N_COLS: {N_COLS}')
# Out:
# # HAND_IDXS: 21, N_COLS: 66

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
LIPS_START = 0
LEFT_HAND_START = LIPS_IDXS.size
RIGHT_HAND_START = LEFT_HAND_START + LEFT_HAND_IDXS.size
POSE_START = RIGHT_HAND_START + RIGHT_HAND_IDXS.size

print(f'LIPS_START: {LIPS_START}, LEFT_HAND_START: {LEFT_HAND_START}, RIGHT_HAND_START: {RIGHT_HAND_START}, POSE_START: {POSE_START}')
# Out:
# LIPS_START: 0, LEFT_HAND_START: 40, RIGHT_HAND_START: 61, POSE_START: 61

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
ROWS_PER_FRAME = 543  # number of landmarks per frame
def load_and_preprocess_data(file_path, preprocess_layer):
    # Load data
    data_columns = ['x', 'y', 'z']
    data = pd.read_parquet(file_path, columns=data_columns)
    n_frames = int(len(data) / ROWS_PER_FRAME)
    data = data.values.reshape(n_frames, ROWS_PER_FRAME, len(data_columns))
    # Apply preprocessing using the PreprocessLayer
    processed_data = preprocess_layer(data.astype(np.float32))

    return processed_data

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
# If True, processing data from scratch
# If False, loads preprocessed data
PREPROCESS_DATA = False
TRAIN_MODEL = True
# True: use 10% of participants as validation set
# False: use all data for training -> gives better LB result
USE_VAL = False

N_ROWS = 543
N_DIMS = 3
DIM_NAMES = ['x', 'y', 'z']
SEED = 42
NUM_CLASSES = 250
IS_INTERACTIVE = True
VERBOSE = 1 if IS_INTERACTIVE else 2

INPUT_SIZE = 64

BATCH_ALL_SIGNS_N = 4
BATCH_SIZE = 256
N_EPOCHS = 100
LR_MAX = 1e-3
N_WARMUP_EPOCHS = 0
WD_RATIO = 0.05
MASK_VAL = 4237

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
class PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(PreprocessLayer, self).__init__()
        normalisation_correction = tf.constant([
                    # Add 0.50 to left hand (original right hand) and substract 0.50 of right hand (original left hand)
                    [0] * len(LIPS_IDXS) + [0.50] * len(LEFT_HAND_IDXS) + [0.50] * len(POSE_IDXS),
                    # Y coordinates stay intact
                    [0] * len(LANDMARK_IDXS_LEFT_DOMINANT0),
                    # Z coordinates stay intact
                    [0] * len(LANDMARK_IDXS_LEFT_DOMINANT0),
                ],
                dtype=tf.float32,
            )
        self.normalisation_correction = tf.transpose(normalisation_correction, [1,0])

    def pad_edge(self, t, repeats, side):
        if side == 'LEFT':
            return tf.concat((tf.repeat(t[:1], repeats=repeats, axis=0), t), axis=0)
        elif side == 'RIGHT':
            return tf.concat((t, tf.repeat(t[-1:], repeats=repeats, axis=0)), axis=0)

    @tf.function(
        input_signature=(tf.TensorSpec(shape=[None,N_ROWS,N_DIMS], dtype=tf.float32),),
    )
    def call(self, data0):
        # Number of Frames in Video
        N_FRAMES0 = tf.shape(data0)[0]

        # Find dominant hand by comparing summed absolute coordinates
        left_hand_sum = tf.math.reduce_sum(tf.where(tf.math.is_nan(tf.gather(data0, LEFT_HAND_IDXS0, axis=1)), 0, 1))
        right_hand_sum = tf.math.reduce_sum(tf.where(tf.math.is_nan(tf.gather(data0, RIGHT_HAND_IDXS0, axis=1)), 0, 1))
        left_dominant = left_hand_sum >= right_hand_sum

        # Count non NaN Hand values in each frame for the dominant hand
        if left_dominant:
            frames_hands_non_nan_sum = tf.math.reduce_sum(
                    tf.where(tf.math.is_nan(tf.gather(data0, LEFT_HAND_IDXS0, axis=1)), 0, 1),
                    axis=[1, 2],
                )
        else:
            frames_hands_non_nan_sum = tf.math.reduce_sum(
                    tf.where(tf.math.is_nan(tf.gather(data0, RIGHT_HAND_IDXS0, axis=1)), 0, 1),
                    axis=[1, 2],
                )

        # Find frames indices with coordinates of dominant hand
        non_empty_frames_idxs = tf.where(frames_hands_non_nan_sum > 0)
        non_empty_frames_idxs = tf.squeeze(non_empty_frames_idxs, axis=1)
        # Filter frames
        data = tf.gather(data0, non_empty_frames_idxs, axis=0)

        # Cast Indices in float32 to be compatible with Tensorflow Lite
        non_empty_frames_idxs = tf.cast(non_empty_frames_idxs, tf.float32)
        # Normalize to start with 0
        non_empty_frames_idxs -= tf.reduce_min(non_empty_frames_idxs)

        # Number of Frames in Filtered Video
        N_FRAMES = tf.shape(data)[0]

        # Gather Relevant Landmark Columns
        if left_dominant:
            data = tf.gather(data, LANDMARK_IDXS_LEFT_DOMINANT0, axis=1)
        else:
            data = tf.gather(data, LANDMARK_IDXS_RIGHT_DOMINANT0, axis=1)
            data = (
                    self.normalisation_correction + (
                        (data - self.normalisation_correction) * tf.where(self.normalisation_correction != 0, -1.0, 1.0))
                )

        # Video fits in INPUT_SIZE
        if N_FRAMES < INPUT_SIZE:
            # Pad With -1 to indicate padding
            non_empty_frames_idxs = tf.pad(non_empty_frames_idxs, [[0, INPUT_SIZE-N_FRAMES]], constant_values=-1)
            # Pad Data With Zeros
            data = tf.pad(data, [[0, INPUT_SIZE-N_FRAMES], [0,0], [0,0]], constant_values=0)
            # Fill NaN Values With 0
            data = tf.where(tf.math.is_nan(data), 0.0, data)
            return data, non_empty_frames_idxs
        # Video needs to be downsampled to INPUT_SIZE
        else:
            # Repeat
            if N_FRAMES < INPUT_SIZE**2:
                repeats = tf.math.floordiv(INPUT_SIZE * INPUT_SIZE, N_FRAMES0)
                data = tf.repeat(data, repeats=repeats, axis=0)
                non_empty_frames_idxs = tf.repeat(non_empty_frames_idxs, repeats=repeats, axis=0)

            # Pad To Multiple Of Input Size
            pool_size = tf.math.floordiv(len(data), INPUT_SIZE)
            if tf.math.mod(len(data), INPUT_SIZE) > 0:
                pool_size += 1

            if pool_size == 1:
                pad_size = (pool_size * INPUT_SIZE) - len(data)
            else:
                pad_size = (pool_size * INPUT_SIZE) % len(data)

            # Pad Start/End with Start/End value
            pad_left = tf.math.floordiv(pad_size, 2) + tf.math.floordiv(INPUT_SIZE, 2)
            pad_right = tf.math.floordiv(pad_size, 2) + tf.math.floordiv(INPUT_SIZE, 2)
            if tf.math.mod(pad_size, 2) > 0:
                pad_right += 1

            # Pad By Concatenating Left/Right Edge Values
            data = self.pad_edge(data, pad_left, 'LEFT')
            data = self.pad_edge(data, pad_right, 'RIGHT')

            # Pad Non Empty Frame Indices
            non_empty_frames_idxs = self.pad_edge(non_empty_frames_idxs, pad_left, 'LEFT')
            non_empty_frames_idxs = self.pad_edge(non_empty_frames_idxs, pad_right, 'RIGHT')

            # Reshape to Mean Pool
            data = tf.reshape(data, [INPUT_SIZE, -1, N_COLS, N_DIMS])
            non_empty_frames_idxs = tf.reshape(non_empty_frames_idxs, [INPUT_SIZE, -1])

            # Mean Pool
            data = tf.experimental.numpy.nanmean(data, axis=1)
            non_empty_frames_idxs = tf.experimental.numpy.nanmean(non_empty_frames_idxs, axis=1)

            # Fill NaN Values With 0
            data = tf.where(tf.math.is_nan(data), 0.0, data)

            return data, non_empty_frames_idxs

preprocess_layer = PreprocessLayer()

# %%
# Code From https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
# Function to preprocess the entire dataset
def preprocess_data(df, main_dir, preprocess_layer):
    X = np.zeros([len(df), INPUT_SIZE, N_COLS, N_DIMS], dtype=np.float32)
    y = np.zeros([len(df)], dtype=np.int32)
    NON_EMPTY_FRAME_IDXS = np.full([len(df), INPUT_SIZE], -1, dtype=np.float32)

    for row_idx, row in tqdm(df.iterrows(), total=len(df)):
        file_path = os.path.join(main_dir, row['path'])
        processed_data, non_empty_frame_idxs = load_and_preprocess_data(file_path, preprocess_layer)
        X[row_idx] = processed_data
        y[row_idx] = row['sign_index']
        NON_EMPTY_FRAME_IDXS[row_idx] = non_empty_frame_idxs
    # Save processed data
    np.save(os.path.join(googledrive_dir, 'X.npy'), X)
    np.save(os.path.join(googledrive_dir, 'y.npy'), y)
    np.save(os.path.join(googledrive_dir, 'NON_EMPTY_FRAME_IDXS.npy'), NON_EMPTY_FRAME_IDXS)

    # Optional: Train-Validation Split
    splitter = GroupShuffleSplit(test_size=0.10, n_splits=2, random_state=42)
    train_idxs, val_idxs = next(splitter.split(X, y, groups=df['participant_id']))

    # Save Train and Validation Sets
    X_train = X[train_idxs]
    NON_EMPTY_FRAME_IDXS_TRAIN = NON_EMPTY_FRAME_IDXS[train_idxs]
    y_train = y[train_idxs]
    np.save(os.path.join(googledrive_dir, 'X_train.npy'), X[train_idxs])
    np.save(os.path.join(googledrive_dir, 'y_train.npy'), y[train_idxs])
    np.save(os.path.join(googledrive_dir, 'NON_EMPTY_FRAME_IDXS_TRAIN.npy'), NON_EMPTY_FRAME_IDXS_TRAIN)
    X_val = X[val_idxs]
    NON_EMPTY_FRAME_IDXS_VAL = NON_EMPTY_FRAME_IDXS[val_idxs]
    y_val = y[val_idxs]
    np.save(os.path.join(googledrive_dir, 'X_val.npy'), X[val_idxs])
    np.save(os.path.join(googledrive_dir, 'y_val.npy'), y[val_idxs])
    np.save(os.path.join(googledrive_dir, 'NON_EMPTY_FRAME_IDXS_VAL.npy'), NON_EMPTY_FRAME_IDXS_VAL)

# Run the preprocessing
preprocess_data(df_metadata, main_dir, preprocess_layer)
# Out:
# 100%|██████████| 94477/94477 [21:41<00:00, 72.61it/s]

# %% [markdown]
# Reference:
#
# Wijkhuizen, M. (2023, April 04). GISLR TF Data Processing & Transformer Training. Kaggle. https://www.kaggle.com/code/markwijkhuizen/gislr-tf-data-processing-transformer-training
